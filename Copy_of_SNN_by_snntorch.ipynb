# %% [markdown]
# # snnTorch - Training Spiking Neural Networks with snnTorch
# ## NARENDRANATH rALAPANAWA janitha kirana
# #here we have use snntorch tutorial 5 and we implemented more computational effitiant algo in training method in this doc after custom approximation part done by us

# %%
# !pip install snntorch
# Out:
# Collecting snntorch
#   Downloading snntorch-0.9.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from snntorch) (2.3.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from snntorch) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from snntorch) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from snntorch) (1.25.2)
# Collecting nir (from snntorch)
#   Downloading nir-1.0.4-py3-none-any.whl (18 kB)
# Collecting nirtorch (from snntorch)
#   Downloading nirtorch-1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.1.0->snntorch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 35.9 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from nir->snntorch) (3.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->snntorch) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->snntorch) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->snntorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1.0->snntorch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nir, nvidia-cusolver-cu12, nirtorch, snntorch
# Successfully installed nir-1.0.4 nirtorch-1.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 snntorch-0.9.1

# %%
# imports
import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import numpy as np
import itertools

# %% [markdown]
# # 1. A Recurrent Representation of SNNs

# %% [markdown]
# In Tutorial 3, we derived a recursive representation of a leaky integrate-and-fire (LIF) neuron:
#
# $$U[t+1] = \underbrace{\beta U[t]}_\text{decay} + \underbrace{WX[t+1]}_\text{input} - \underbrace{R[t]}_\text{reset} \tag{1}$$
#
# where the input synaptic current is interpreted as $I_{\rm in}[t] = WX[t]$, and $X[t]$ may be some arbitrary input of spikes, a step/time-varying voltage, or unweighted step/time-varying current. Spiking is represented with the following equation, where if the membrane potential exceeds the threshold, a spike is emitted:
#
# $$S[t] = \begin{cases} 1, &\text{if}~U[t] > U_{\rm thr} \\
# 0, &\text{otherwise}\end{cases} \tag{2}$$
#
# This formulation of a spiking neuron in a discrete, recursive form is almost perfectly poised to take advantage of the developments in training recurrent neural networks (RNNs) and sequence-based models. This is illustrated using an *implicit* recurrent connection for the decay of the membrane potential, and is distinguished from *explicit* recurrence where the output spike $S_{\rm out}$ is fed back to the input. In the figure below, the connection weighted by $-U_{\rm thr}$ represents the reset mechanism $R[t]$.
#
#
# <center>
# <img src='https://github.com/jeshraghian/snntorch/blob/master/docs/_static/img/examples/tutorial5/unrolled_2.png?raw=true' width="800">
# </center>
#
# The benefit of an unrolled graph is that it provides an explicit description of how computations are performed. The process of unfolding illustrates the flow of information forward in time (from left to right) to compute outputs and losses, and backward in time to compute gradients. The more time steps that are simulated, the deeper the graph becomes.
#
# Conventional RNNs treat $\beta$ as a learnable parameter. This is also possible for SNNs, though by default, they are treated as hyperparameters. This replaces the vanishing and exploding gradient problems with a hyperparameter search. A future tutorial will describe how to make $\beta$ a learnable parameter.

# %% [markdown]
# # 2. The Non-Differentiability of Spikes
# ## 2.1 Training Using the Backprop Algorithm
#
# An alternative way to represent the relationship between $S$ and $U$ in $(2)$ is:
#
# $$S[t] = \Theta(U[t] - U_{\rm thr}) \tag{3}$$
#
# where $\Theta(\cdot)$ is the Heaviside step function:
#
# <center>
# <img src='https://github.com/jeshraghian/snntorch/blob/master/docs/_static/img/examples/tutorial3/3_2_spike_descrip.png?raw=true' width="600">
# </center>
#
# Training a network in this form poses some serious challenges. Consider a single, isolated time step of the computational graph from the previous figure titled *"Recurrent representation of spiking neurons"*, as shown in the *forward pass* below:
#
# <center>
# <img src='https://github.com/jeshraghian/snntorch/blob/master/docs/_static/img/examples/tutorial5/non-diff.png?raw=true' width="400">
# </center>
#
# The goal is to train the network using the gradient of the loss with respect to the weights, such that the weights are updated to minimize the loss. The backpropagation algorithm achieves this using the chain rule:
#
# $$\frac{\partial \mathcal{L}}{\partial W} =
# \frac{\partial \mathcal{L}}{\partial S}
# \underbrace{\frac{\partial S}{\partial U}}_{\{0, \infty\}}
# \frac{\partial U}{\partial I}\
# \frac{\partial I}{\partial W}\ \tag{4}$$
#
# From $(1)$, $\partial I/\partial W=X$, and $\partial U/\partial I=1$. While we have not yet defined a loss function, we can assume $\partial \mathcal{L}/\partial S$ has an analytical solution, in a similar form to the cross-entropy or mean-square error loss (more on that shortly).
#
# However, the term that we are going to grapple with is $\partial S/\partial U$. The derivative of the Heaviside step function from $(3)$ is the Dirac Delta function, which evaluates to 0 everywhere, except at the threshold $U_{\rm thr} = \theta$, where it tends to infinity. This means the gradient will almost always be nulled to zero (or saturated if $U$ sits precisely at the threshold), and no learning can take place. This is known as the **dead neuron problem**.

# %% [markdown]
# ## 2.2 Overcoming the Dead Neuron Problem
#
# The most common way to address the dead neuron problem is to keep the Heaviside function as it is during the forward pass, but swap the derivative term $\partial S/\partial U$ for something that does not kill the learning process during the backward pass, which will be denoted $\partial \tilde{S}/\partial U$. This might sound odd, but it turns out that neural networks are quite robust to such approximations. This is commonly known as the *surrogate gradient* approach.
#
# A variety of options exist to using surrogate gradients, and we will dive into more detail on these methods in [Tutorial 6](https://snntorch.readthedocs.io/en/latest/tutorials/index.html). The default method in snnTorch (as of v0.6.0) is to smooth the Heaviside function with the arctangent function. The backward-pass derivative used is:
#
# $$ \frac{\partial \tilde{S}}{\partial U} \leftarrow \frac{1}{\pi}\frac{1}{(1+[U\pi]^2)} \tag{5}$$
#
# where the left arrow denotes substitution.
#
# The same neuron model described in  $(1)-(2)$ (a.k.a., `snn.Leaky` neuron from Tutorial 3) is implemented in PyTorch below. Don't worry if you don't understand this. This will be condensed into one line of code using snnTorch in a moment:

# %%
# Leaky neuron model, overriding the backward pass with a custom function
class LeakySurrogate(nn.Module):
  def __init__(self, beta, threshold=1.0):
      super(LeakySurrogate, self).__init__()

      # initialize decay rate beta and threshold
      self.beta = beta
      self.threshold = threshold
      self.spike_gradient = self.ATan.apply

  # the forward function is called each time we call Leaky
  def forward(self, input_, mem):
    spk = self.spike_gradient((mem-self.threshold))  # call the Heaviside function
    reset = (self.beta * spk * self.threshold).detach() # remove reset from computational graph
    mem = self.beta * mem + input_ - reset # Eq (1)
    return spk, mem

  # Forward pass: Heaviside function
  # Backward pass: Override Dirac Delta with the ArcTan function
  @staticmethod
  class ATan(torch.autograd.Function):
      @staticmethod
      def forward(ctx, mem):
          spk = (mem > 0).float() # Heaviside on the forward pass: Eq(2)
          ctx.save_for_backward(mem)  # store the membrane for use in the backward pass
          return spk

      @staticmethod
      def backward(ctx, grad_output):
          (mem,) = ctx.saved_tensors  # retrieve the membrane potential
          grad = 1 / (1 + (np.pi * mem).pow_(2)) * grad_output # Eqn 5
          return grad

# %% [markdown]
# Note that the reset mechanism is detached from the computational graph, as the surrogate gradient should only be applied to $\partial S/\partial U$, and not $\partial R/\partial U$.
#
# The above neuron is instantiated using:

# %%
lif1 = LeakySurrogate(beta=0.9)

# %% [markdown]
# This neuron can be simulated using a for-loop, just as in previous tutorials, while PyTorch's automatic differentation (autodiff) mechanism keeps track of the gradient in the background.
#
# Alternatively, the same thing can be accomplished by calling the `snn.Leaky` neuron.
# In fact, every time you call any neuron model from snnTorch, the *ATan* surrogate gradient is applied to it by default:

# %%
lif1 = snn.Leaky(beta=0.9)

# %% [markdown]
# If you would like to explore how this neuron behaves, then refer to [Tutorial 3](https://snntorch.readthedocs.io/en/latest/tutorials/index.html).

# %% [markdown]
# #3. Backprop Through Time
# Equation $(4)$ only calculates the gradient for one single time step (referred to as the *immediate influence* in the figure below), but the backpropagation through time (BPTT) algorithm calculates the gradient from the loss to *all* descendants and sums them together.
#
# The weight $W$ is applied at every time step, and so imagine a loss is also calculated at every time step. The influence of the weight on present and historical losses must be summed together to define the global gradient:
#
# $$\frac{\partial \mathcal{L}}{\partial W}=\sum_t \frac{\partial\mathcal{L}[t]}{\partial W} =
# \sum_t \sum_{s\leq t} \frac{\partial\mathcal{L}[t]}{\partial W[s]}\frac{\partial W[s]}{\partial W} \tag{5} $$
#
# The point of $(5)$ is to ensure causality: by constraining $s\leq t$, we only account for the contribution of immediate and prior influences of $W$ on the loss. A recurrent system constrains the weight to be shared across all steps: $W[0]=W[1] =~... ~ = W$. Therefore, a change in $W[s]$ will have the same effect on all $W$, which implies that $\partial W[s]/\partial W=1$:
#
# $$\frac{\partial \mathcal{L}}{\partial W}=
# \sum_t \sum_{s\leq t} \frac{\partial\mathcal{L}[t]}{\partial W[s]} \tag{6} $$
#
# As an example, isolate the prior influence due to $s = t-1$ *only*; this means the backward pass must track back in time by one step. The influence of $W[t-1]$ on the loss can be written as:
#
# $$\frac{\partial \mathcal{L}[t]}{\partial W[t-1]} =
# \frac{\partial \mathcal{L}[t]}{\partial S[t]}
# \underbrace{\frac{\partial \tilde{S}[t]}{\partial U[t]}}_{Eq.~(5)}
# \underbrace{\frac{\partial U[t]}{\partial U[t-1]}}_\beta
# \underbrace{\frac{\partial U[t-1]}{\partial I[t-1]}}_1
# \underbrace{\frac{\partial I[t-1]}{\partial W[t-1]}}_{X[t-1]} \tag{7}$$
#
# We have already dealt with all of these terms from $(4)$, except for $\partial U[t]/\partial U[t-1]$. From $(1)$, this temporal derivative term simply evaluates to $\beta$. So if we really wanted to, we now know enough to painstakingly calculate the derivative of every weight at every time step by hand, and it'd look something like this for a single neuron:
#
# <center>
# <img src='https://github.com/jeshraghian/snntorch/blob/master/docs/_static/img/examples/tutorial5/bptt.png?raw=true' width="600">
# </center>
#
# But thankfully, PyTorch's autodiff takes care of that in the background for us.
#
# *Note: The reset mechanism has been omitted from the above figure. In snnTorch, reset is included in the forward-pass, but detached from the backward pass.*

# %% [markdown]
# # 4. Setting up the Loss / Output Decoding
# In a conventional, non-spiking neural network, a supervised, multi-class classification problem takes the neuron with the highest activation and treats that as the predicted class.
#
# In a spiking neural net, there are several options to interpreting the output spikes. The most common approaches are:
# * **Rate coding:** Take the neuron with the highest firing rate (or spike count) as the predicted class
# * **Latency coding:** Take the neuron that fires *first* as the predicted class
#
# This might feel familiar to [Tutorial 1 on neural encoding](https://snntorch.readthedocs.io/en/latest/tutorials/index.html). The difference is that, here, we are interpreting (decoding) the output spikes, rather than encoding/converting raw input data into spikes.
#
# Let's focus on a rate code. When input data is passed to the network, we want the correct neuron class to emit the most spikes over the course of the simulation run. This then corresponds to the highest average firing frequency. One way to achieve this is to increase the membrane potential of the correct class to $U>U_{\rm thr}$, and that of incorrect classes to $U<U_{\rm thr}$. Applying the target to $U$ serves as a proxy for modulating spiking behavior from $S$.
#
# This can be implemented by taking the softmax of the membrane potential for output neurons, where $C$ is the number of output classes:
#
# $$p_i[t] = \frac{e^{U_i[t]}}{\sum_{j=0}^{C}e^{U_j[t]}} \tag{8}$$
#
# The cross-entropy between $p_i$ and the target $y_i \in \{0,1\}^C$, which is a one-hot target vector, is obtained using:
#
# $$\mathcal{L}_{CE}[t] = -\sum_{i=0}^Cy_i{\rm log}(p_i[t]) \tag{9}$$
#
# The practical effect is that the membrane potential of the correct class is encouraged to increase while those of incorrect classes are reduced. In effect, this means the correct class is encouraged to fire at all time steps, while incorrect classes are suppressed at all steps. This may not be the most efficient implementation of an SNN, but it is among the simplest.
#
# This target is applied at every time step of the simulation, thus also generating a loss at every step. These losses are then summed together at the end of the simulation:
#
# $$\mathcal{L}_{CE} = \sum_t\mathcal{L}_{CE}[t] \tag{10}$$
#
# This is just one of many possible ways to apply a loss function to a spiking neural network. A variety of approaches are available to use in snnTorch (in the module `snn.functional`), and will be the subject of a future tutorial.
#
# With all of the background theory having been taken care of, let’s finally dive into
# training a fully-connected spiking neural net.

# %% [markdown]
# # 5. Setting up the Static MNIST Dataset

# %%
# dataloader arguments
batch_size = 128
data_path='/tmp/data/mnist'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
# Define a transform
transform = transforms.Compose([
            transforms.Resize((28, 28)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# %% [markdown]
# If the above code blocks throws an error, e.g. the MNIST servers are down, then uncomment the following code instead.

# %%
# # temporary dataloader if MNIST service is unavailable
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

# mnist_train = datasets.MNIST(root = './', train=True, download=True, transform=transform)
# mnist_test = datasets.MNIST(root = './', train=False, download=True, transform=transform)

# %%
# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# %% [markdown]
# # 6. Define the Network

# %%
# Network Architecture
num_inputs = 28*28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.95

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# Load the network onto CUDA if available
net = Net().to(device)

# %% [markdown]
# The code in the `forward()` function will only be called once the input argument `x` is explicitly passed into `net`.
#
# * `fc1` applies a linear transformation to all input pixels from the MNIST dataset;
# * `lif1` integrates the weighted input over time, emitting a spike if the threshold condition is met;
# * `fc2` applies a linear transformation to the output spikes of `lif1`;
# * `lif2` is another spiking neuron layer, integrating the weighted spikes over time.

# %% [markdown]
# # 7. Training the SNN

# %% [markdown]
# ## 7.1 Accuracy Metric
# Below is a function that takes a batch of data, counts up all the spikes from each neuron (i.e., a rate code over the simulation time), and compares the index of the highest count with the actual target. If they match, then the network correctly predicted the target.

# %%
# pass data into the network, sum the spikes over time
# and compare the neuron with the highest number of spikes
# with the target

def print_batch_accuracy(data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
    else:
        print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

def train_printer(
    data, targets, epoch,
    counter, iter_counter,
        loss_hist, test_loss_hist, test_data, test_targets):
    print(f"Epoch {epoch}, Iteration {iter_counter}")
    print(f"Train Set Loss: {loss_hist[counter]:.2f}")
    print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
    print_batch_accuracy(data, targets, train=True)
    print_batch_accuracy(test_data, test_targets, train=False)
    print("\n")

# %% [markdown]
# ## 7.2 Loss Definition
# The `nn.CrossEntropyLoss` function in PyTorch automatically handles taking the softmax of the output layer as well as generating a loss at the output.

# %%
loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## 7.3 Optimizer
# Adam is a robust optimizer that performs well on recurrent networks, so let's use that with a learning rate of $5\times10^{-4}$.

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

# %% [markdown]
# ## 7.4 One Iteration of Training
# Take the first batch of data and load it onto CUDA if available.

# %%
data, targets = next(iter(train_loader))
data = data.to(device)
targets = targets.to(device)

# %% [markdown]
# Flatten the input data to a vector of size $784$ and pass it into the network.

# %%
spk_rec, mem_rec = net(data.view(batch_size, -1))
print(mem_rec.size())
# Out:
# torch.Size([25, 128, 10])

# %% [markdown]
# The recording of the membrane potential is taken across:
# * 25 time steps
# * 128 samples of data
# * 10 output neurons
#
# We wish to calculate the loss at every time step, and sum these up together, as per Equation $(10)$:

# %%
# initialize the total loss value
loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
for step in range(num_steps):
  loss_val += loss(mem_rec[step], targets)

print(f"Training loss: {loss_val.item():.3f}")
# Out:
# Training loss: 59.188

# %% [markdown]
# The loss is quite large, because it is summed over 25 time steps. The accuracy is also bad (it should be roughly around 10%) as the network is untrained:

# %%
print_batch_accuracy(data, targets, train=True)
# Out:
# Train set accuracy for a single minibatch: 10.94%

# %% [markdown]
# A single weight update is applied to the network as follows:

# %%
# clear previously stored gradients
optimizer.zero_grad()

# calculate the gradients
loss_val.backward()

# weight update
optimizer.step()

# %% [markdown]
# Now, re-run the loss calculation and accuracy after a single iteration:

# %%
# calculate new network outputs using the same data
spk_rec, mem_rec = net(data.view(batch_size, -1))

# initialize the total loss value
loss_val = torch.zeros((1), dtype=dtype, device=device)

# sum loss at every step
for step in range(num_steps):
  loss_val += loss(mem_rec[step], targets)

print(f"Training loss: {loss_val.item():.3f}")
print_batch_accuracy(data, targets, train=True)
# Out:
# Training loss: 46.878
# Train set accuracy for a single minibatch: 50.00%

# %% [markdown]
# After only one iteration, the loss should have decreased and accuracy should have increased. Note how membrane potential is used to calculate the cross entropy
# loss, and spike count is used for the measure of accuracy. It is also possible to use the spike count in the loss ([see Tutorial 6](https://snntorch.readthedocs.io/en/latest/tutorials/index.html))

# %% [markdown]
# ## 7.5 Training Loop
#
# Let's combine everything into a training loop. We will train for one epoch (though feel free to increase `num_epochs`), exposing our network to each sample of data once.

# %%
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Outer training loop
for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 50 == 0:
                train_printer(
                    data, targets, epoch,
                    counter, iter_counter,
                    loss_hist, test_loss_hist,
                    test_data, test_targets)
            counter += 1
            iter_counter +=1
# Out:
# Epoch 0, Iteration 0
# Train Set Loss: 53.17
# Test Set Loss: 47.00
# Train set accuracy for a single minibatch: 50.78%
# Test set accuracy for a single minibatch: 47.66%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 12.96
# Test Set Loss: 12.99
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 16.41
# Test Set Loss: 13.04
# Train set accuracy for a single minibatch: 94.53%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 10.26
# Test Set Loss: 6.16
# Train set accuracy for a single minibatch: 88.28%
# Test set accuracy for a single minibatch: 96.09%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 8.56
# Test Set Loss: 9.12
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 7.74
# Test Set Loss: 9.12
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 11.53
# Test Set Loss: 5.59
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 94.53%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 7.18
# Test Set Loss: 6.32
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 96.09%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 12.17
# Test Set Loss: 12.58
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 8.36
# Test Set Loss: 4.24
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 95.31%

# %% [markdown]
# # **using customized transfer functin for backpropergration process**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader

# Leaky neuron model with a custom backward pass using sigmoid surrogate gradient
class LeakySurrogate(nn.Module):
    def __init__(self, beta, threshold=1.0):
        super(LeakySurrogate, self).__init__()
        self.beta = beta
        self.threshold = threshold
        self.spike_gradient = self.Sigmoid.apply

    def forward(self, input_, mem):
        spk = self.spike_gradient(mem - self.threshold)  # call the surrogate gradient function
        reset = (self.beta * spk * self.threshold).detach()  # remove reset from computational graph
        mem = self.beta * mem + input_ - reset  # Eq (1)
        return spk, mem

    # Forward pass: Heaviside function
    # Backward pass: Override Dirac Delta with the derivative of the Sigmoid function
    @staticmethod
    class Sigmoid(torch.autograd.Function):
        @staticmethod
        def forward(ctx, mem):
            spk = (mem > 0).float()  # Heaviside on the forward pass: Eq(2)
            ctx.save_for_backward(mem)  # store the membrane for use in the backward pass
            return spk

        @staticmethod
        def backward(ctx, grad_output):
            mem, = ctx.saved_tensors  # retrieve the membrane potential
            sigmoid = torch.sigmoid(mem)
            grad =
            # Derivative of sigmoid
            #grad = 1 / (1 + (np.pi * mem).pow_(2)) * grad_output
            return grad

# %%
# Network Architecture
num_inputs = 28 * 28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.95

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = LeakySurrogate(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = LeakySurrogate(beta=beta)

    def forward(self, x):
        # Initialize hidden states at t=0
        mem1 = torch.zeros(x.size(0), num_hidden, device=x.device)
        mem2 = torch.zeros(x.size(0), num_outputs, device=x.device)

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Outer training loop
for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")
            counter += 1
            iter_counter += 1
# Out:
# Epoch [1/1], Step [1], Train Loss: 59.3837, Test Loss: 51.2085
# Epoch [1/1], Step [51], Train Loss: 13.2751, Test Loss: 15.0670
# Epoch [1/1], Step [101], Train Loss: 12.6372, Test Loss: 12.1971
# Epoch [1/1], Step [151], Train Loss: 13.1121, Test Loss: 11.0113
# Epoch [1/1], Step [201], Train Loss: 14.2958, Test Loss: 9.1977
# Epoch [1/1], Step [251], Train Loss: 8.2308, Test Loss: 7.9291
# Epoch [1/1], Step [301], Train Loss: 10.4448, Test Loss: 7.3754
# Epoch [1/1], Step [351], Train Loss: 13.0443, Test Loss: 10.6632
# Epoch [1/1], Step [401], Train Loss: 9.2573, Test Loss: 8.4768
# Epoch [1/1], Step [451], Train Loss: 9.5803, Test Loss: 9.0345

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Outer training loop
for epoch in range(num_epochs):
    epoch_start_time = time.time()
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        iter_start_time = time.time()

        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

              #Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")

        iter_end_time = time.time()
        iter_latency = iter_end_time - iter_start_time
        throughput = batch_size / iter_latency
        print(f"Iteration [{iter_counter + 1}] Latency: {iter_latency:.4f}s, Throughput: {throughput:.2f} samples/s")

        counter += 1
        iter_counter += 1

    epoch_end_time = time.time()
    epoch_latency = epoch_end_time - epoch_start_time
    epoch_throughput = len(train_loader.dataset) / epoch_latency
    print(f"Epoch [{epoch + 1}/{num_epochs}] Latency: {epoch_latency:.4f}s, Throughput: {epoch_throughput:.2f} samples/s")
# Out:
# Epoch [1/1], Step [1], Train Loss: 61.0434, Test Loss: 56.2238
# Iteration [1] Latency: 0.7487s, Throughput: 170.96 samples/s
# Iteration [2] Latency: 0.6299s, Throughput: 203.21 samples/s
# Iteration [3] Latency: 0.5526s, Throughput: 231.63 samples/s
# Iteration [4] Latency: 0.3938s, Throughput: 325.06 samples/s
# Iteration [5] Latency: 0.3680s, Throughput: 347.81 samples/s
# Iteration [6] Latency: 0.3732s, Throughput: 342.99 samples/s
# Iteration [7] Latency: 0.3715s, Throughput: 344.59 samples/s
# Iteration [452] Latency: 0.3808s, Throughput: 336.15 samples/s
# Iteration [453] Latency: 0.3727s, Throughput: 343.44 samples/s
# Iteration [454] Latency: 0.3835s, Throughput: 333.74 samples/s
# Iteration [455] Latency: 0.3751s, Throughput: 341.23 samples/s
# Iteration [456] Latency: 0.3811s, Throughput: 335.84 samples/s
# Iteration [457] Latency: 0.3821s, Throughput: 334.98 samples/s
# Iteration [458] Latency: 0.3791s, Throughput: 337.62 samples/s
# Iteration [459] Latency: 0.5911s, Throughput: 216.54 samples/s
# Iteration [460] Latency: 0.5800s, Throughput: 220.70 samples/s
# Iteration [461] Latency: 0.5927s, Throughput: 215.96 samples/s
# Iteration [462] Latency: 0.6017s, Throughput: 212.74 samples/s
# Iteration [463] Latency: 0.5706s, Throughput: 224.33 samples/s
# Iteration [464] Latency: 0.3879s, Throughput: 329.98 samples/s
# Iteration [465] Latency: 0.3859s, Throughput: 331.67 samples/s
# Iteration [466] Latency: 0.3674s, Throughput: 348.42 samples/s
# Iteration [467] Latency: 0.3819s, Throughput: 335.15 samples/s
# Iteration [468] Latency: 0.3691s, Throughput: 346.75 samples/s
# Epoch [1/1] Latency: 211.4441s, Throughput: 283.76 samples/s

# %% [markdown]
# If this was your first time training an SNN, then congratulations!

# %% [markdown]
# # 8. Results
# ## 8.1 Plot Training/Test Loss

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# The loss curves are noisy because the losses are tracked at every iteration, rather than averaging across multiple iterations.

# %% [markdown]
# # Here I am going to find the Polynomial Approximation

# %% [markdown]
# Chebyshev Polynomial Approximation
# Chebyshev polynomials are particularly useful because they minimize the maximum error between the polynomial and the target function, which is desirable for approximating discontinuous functions.
#
# Define the Unit Step Function:
#
# 𝐻
# (
# 𝑥
# )
# =
# {
# 0
# if
# 𝑥
# <
# 0
# 1
# if
# 𝑥
# ≥
# 0
# H(x)={
# 0
# 1
# ​Q
# if x<0
# if x≥0
# ​
#
# Chebyshev Polynomial Approximation:
# The Chebyshev approximation aims to find a polynomial
# 𝑃
# 𝑛
# (
# 𝑥
# )
# P
# n
# ​
#  (x) that approximates
# 𝐻
# (
# 𝑥
# )
# H(x).
#
# Let's go through the steps to approximate the unit step function using Chebyshev polynomials.
#
# Steps:
# Define the interval of approximation:
# Typically, for simplicity, we approximate the unit step function on the interval
# [
# −
# 1
# ,
# 1
# ]
# [−1,1].
#
# Construct the Chebyshev nodes:
# Chebyshev nodes are the roots of Chebyshev polynomials of the first kind
# 𝑇
# 𝑛
# (
# 𝑥
# )
# T
# n
# ​
#  (x), which are given by:
#
# 𝑥
# 𝑖
# =
# cos
# ⁡
# (
# 2
# 𝑖
# +
# 1
# 2
# 𝑛
# 𝜋
# )
# for
# 𝑖
# =
# 0
# ,
# 1
# ,
# …
# ,
# 𝑛
# −
# 1
# x
# i
# ​
#  =cos(
# 2n
# 2i+1
# ​
#  π)for i=0,1,…,n−1
# Evaluate the function at Chebyshev nodes:
# Evaluate
# 𝐻
# (
# 𝑥
# )
# H(x) at these nodes.
#
# Compute the Chebyshev coefficients:
# Use the discrete Chebyshev transform to find the coefficients.
#
# Form the polynomial:
# Combine the Chebyshev coefficients to form the polynomial approximation.
#
# Let's implement these steps to find a polynomial approximation for the unit step function. I'll use Python to perform the calculations.

# %% [markdown]
# # Chebyshev Polynomial Approximation

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.chebyshev import Chebyshev

# Define the unit step function
def unit_step(x):
    return np.where(x >= 0, 1, 0)

# Number of Chebyshev polynomials
n = 10  # You can adjust this value for a better approximation

# Chebyshev nodes
nodes = np.cos((2 * np.arange(n) + 1) * np.pi / (2 * n))

# Evaluate the unit step function at the nodes
values = unit_step(nodes)

# Compute the Chebyshev coefficients
coeffs = np.polynomial.chebyshev.chebfit(nodes, values, n-1)

# Create the Chebyshev polynomial
cheb_poly = Chebyshev(coeffs)

# Plot the approximation
x = np.linspace(-1, 1, 400)
y_true = unit_step(x)
y_approx = cheb_poly(x)

plt.plot(x, y_true, label='Unit Step Function')
plt.plot(x, y_approx, label='Chebyshev Approximation')
plt.legend()
plt.xlabel('x')
plt.ylabel('H(x)')
plt.title('Chebyshev Polynomial Approximation of the Unit Step Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.chebyshev import Chebyshev

# Define the unit step function
def unit_step(x):
    return np.where(x >= 0, 1, 0)

# Number of Chebyshev polynomials
n = 100  # You can adjust this value for a better approximation

# Chebyshev nodes
nodes = np.cos((2 * np.arange(n) + 1) * np.pi / (2 * n))

# Evaluate the unit step function at the nodes
values = unit_step(nodes)

# Compute the Chebyshev coefficients
coeffs = np.polynomial.chebyshev.chebfit(nodes, values, n-1)

# Create the Chebyshev polynomial
cheb_poly = Chebyshev(coeffs)

# Compute the derivative of the Chebyshev polynomial
cheb_poly_derivative = cheb_poly.deriv()

# Evaluate the polynomials at a range of x values
x = np.linspace(-1, 1, 400)
y_true = unit_step(x)
y_approx = cheb_poly(x)
y_approx_derivative = cheb_poly_derivative(x)

# Plot the original function, its approximation, and the gradient
plt.figure(figsize=(12, 6))

# Plot the unit step function and its approximation
plt.subplot(2, 1, 1)
plt.plot(x, y_true, label='Unit Step Function')
plt.plot(x, y_approx, label='Chebyshev Approximation')
plt.legend()
plt.xlabel('x')
plt.ylabel('H(x)')
plt.title('Chebyshev Polynomial Approximation of the Unit Step Function')
plt.grid(True)

# Plot the gradient of the Chebyshev approximation
plt.subplot(2, 1, 2)
plt.plot(x, y_approx_derivative, label='Gradient of Chebyshev Approximation', color='orange')
plt.legend()
plt.xlabel('x')
plt.ylabel("H'(x)")
plt.title('Gradient of the Chebyshev Polynomial Approximation')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.chebyshev import Chebyshev

# Define the shifted unit step function
def shifted_unit_step(x, a):
    return np.where(x >= a, 1, 0)

# Number of Chebyshev polynomials
n = 100  # You can adjust this value for a better approximation

# Shift point
a = 1  # Change this to the desired shift point

# Chebyshev nodes
nodes = np.cos((2 * np.arange(n) + 1) * np.pi / (2 * n))

# Evaluate the shifted unit step function at the nodes
values = shifted_unit_step(nodes, a)

# Compute the Chebyshev coefficients
coeffs = np.polynomial.chebyshev.chebfit(nodes, values, n-1)

# Create the Chebyshev polynomial
cheb_poly = Chebyshev(coeffs)

# Compute the derivative of the Chebyshev polynomial
cheb_poly_derivative = cheb_poly.deriv()

# Evaluate the polynomials at a range of x values
x = np.linspace(-100, 100, 400)
y_true = shifted_unit_step(x, a)
y_approx = cheb_poly(x)
y_approx_derivative = cheb_poly_derivative(x)

# Plot the original function, its approximation, and the gradient
plt.figure(figsize=(12, 6))

# Plot the shifted unit step function and its approximation
plt.subplot(2, 1, 1)
plt.plot(x, y_true, label='Shifted Unit Step Function')
plt.plot(x, y_approx, label='Chebyshev Approximation')
plt.legend()
plt.xlabel('x')
plt.ylabel('H(x)')
plt.title('Chebyshev Polynomial Approximation of the Shifted Unit Step Function')
plt.grid(True)

# Plot the gradient of the Chebyshev approximation
plt.subplot(2, 1, 2)
plt.plot(x, y_approx_derivative, label='Gradient of Chebyshev Approximation', color='orange')
plt.legend()
plt.xlabel('x')
plt.ylabel("H'(x)")
plt.title('Gradient of the Chebyshev Polynomial Approximation')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Neuron with chebyshev approximations

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.chebyshev import Chebyshev

# Leaky neuron model with a custom backward pass using sigmoid surrogate gradient
class Leaky_cheb(nn.Module):



# Define the shifted unit step function
    def shifted_unit_step(x, a):
        return np.where(x >= a, 1, 0)

    # Number of Chebyshev polynomials
    n = 4  # You can adjust this value for a better approximation

    # Shift point
    a = 1  # Change this to the desired shift point

    # Chebyshev nodes
    nodes = np.cos((2 * np.arange(n) + 1) * np.pi / (2 * n))

    # Evaluate the shifted unit step function at the nodes
    values = shifted_unit_step(nodes, a)

    # Compute the Chebyshev coefficients
    coeffs = np.polynomial.chebyshev.chebfit(nodes, values, n-1)

    # Create the Chebyshev polynomial
    cheb_poly = Chebyshev(coeffs)

    # Compute the derivative of the Chebyshev polynomial
    cheb_poly_derivative = cheb_poly.deriv()

    # Evaluate the polynomials at a range of x values
    x = np.linspace(-1, 1, 400)
    y_true = shifted_unit_step(x, a)
    #y_approx = cheb_poly(x)
    #y_approx_derivative = cheb_poly_derivative(x)

    def __init__(self, beta, threshold=1.0):
        super(Leaky_cheb, self).__init__()
        self.beta = beta
        self.threshold = threshold
        self.spike_gradient = self.Sigmoid.apply

    def forward(self, input_, mem):
        spk = self.spike_gradient(mem - self.threshold)  # call the surrogate gradient function
        reset = (self.beta * spk * self.threshold).detach()  # remove reset from computational graph
        mem = self.beta * mem + input_ - reset  # Eq (1)
        return spk, mem

    # Forward pass: Heaviside function
    # Backward pass: Override Dirac Delta with the derivative of the Sigmoid function
    @staticmethod
    class Sigmoid(torch.autograd.Function):
        @staticmethod
        def forward(ctx, mem):
            spk = (mem > 0).float()  # Heaviside on the forward pass: Eq(2)
            ctx.save_for_backward(mem)  # store the membrane for use in the backward pass
            return spk

        @staticmethod
        def backward(ctx, grad_output):
            mem, = ctx.saved_tensors  # retrieve the membrane potential
            sigmoid = torch.sigmoid(mem)
            #grad = sigmoid * (1 - sigmoid) * grad_output  # Derivative of sigmoid
            #grad = 1 / (1 + (np.pi * mem).pow_(2)) * grad_output
            grad=cheb_poly_derivative(mem)
            return grad

# %%
# Network Architecture
num_inputs = 28 * 28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.95

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = Leaky_cheb(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = Leaky_cheb(beta=beta)

    def forward(self, x):
        # Initialize hidden states at t=0
        mem1 = torch.zeros(x.size(0), num_hidden, device=x.device)
        mem2 = torch.zeros(x.size(0), num_outputs, device=x.device)

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Outer training loop
for epoch in range(num_epochs):
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

            # Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")
            counter += 1
            iter_counter += 1
# Out:
# Epoch [1/1], Step [1], Train Loss: 61.4720, Test Loss: 58.0393
# Epoch [1/1], Step [51], Train Loss: 30.9620, Test Loss: 29.8554
# Epoch [1/1], Step [101], Train Loss: 22.9860, Test Loss: 21.9187
# Epoch [1/1], Step [151], Train Loss: 26.1112, Test Loss: 21.6523
# Epoch [1/1], Step [201], Train Loss: 24.2564, Test Loss: 19.1174
# Epoch [1/1], Step [251], Train Loss: 17.8293, Test Loss: 17.1713
# Epoch [1/1], Step [301], Train Loss: 19.8524, Test Loss: 18.1654
# Epoch [1/1], Step [351], Train Loss: 16.3469, Test Loss: 15.5651
# Epoch [1/1], Step [401], Train Loss: 17.8928, Test Loss: 16.6962
# Epoch [1/1], Step [451], Train Loss: 16.2535, Test Loss: 14.8998

# %% [markdown]
# # To find throuput and latancy of training process

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Outer training loop
for epoch in range(num_epochs):
    epoch_start_time = time.time()
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        iter_start_time = time.time()

        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

              #Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")

        iter_end_time = time.time()
        iter_latency = iter_end_time - iter_start_time
        throughput = batch_size / iter_latency
        print(f"Iteration [{iter_counter + 1}] Latency: {iter_latency:.4f}s, Throughput: {throughput:.2f} samples/s")

        counter += 1
        iter_counter += 1

    epoch_end_time = time.time()
    epoch_latency = epoch_end_time - epoch_start_time
    epoch_throughput = len(train_loader.dataset) / epoch_latency
    print(f"Epoch [{epoch + 1}/{num_epochs}] Latency: {epoch_latency:.4f}s, Throughput: {epoch_throughput:.2f} samples/s")
# Out:
# Epoch [1/1], Step [1], Train Loss: 62.1341, Test Loss: 57.6933
# Iteration [1] Latency: 1.2224s, Throughput: 104.72 samples/s
# Iteration [2] Latency: 1.3039s, Throughput: 98.16 samples/s
# Iteration [3] Latency: 1.2959s, Throughput: 98.77 samples/s
# Iteration [4] Latency: 0.9831s, Throughput: 130.20 samples/s
# Iteration [5] Latency: 1.0115s, Throughput: 126.55 samples/s
# Iteration [6] Latency: 0.9673s, Throughput: 132.33 samples/s
# Iteration [7] Latency: 0.9731s, Throughput: 131.54 samples/s
# Iteration [8] Latency: 0.9881s, Throughput: 129.54 samples/s
# Iteration [9] Latency: 0.9888s, Throughput: 129.45 samples/s
# Iteration [10] Latency: 1.2790s, Throughput: 100.08 samples/s
# Iteration [11] Latency: 1.3205s, Throughput: 96.93 samples/s
# Iteration [12] Latency: 1.4129s, Throughput: 90.59 samples/s
# Iteration [13] Latency: 1.2878s, Throughput: 99.40 samples/s
# Iteration [457] Latency: 1.2674s, Throughput: 101.00 samples/s
# Iteration [458] Latency: 1.5361s, Throughput: 83.33 samples/s
# Iteration [459] Latency: 1.5205s, Throughput: 84.19 samples/s
# Iteration [460] Latency: 1.4950s, Throughput: 85.62 samples/s
# Iteration [461] Latency: 1.1990s, Throughput: 106.76 samples/s
# Iteration [462] Latency: 1.0762s, Throughput: 118.94 samples/s
# Iteration [463] Latency: 0.9621s, Throughput: 133.04 samples/s
# Iteration [464] Latency: 0.9809s, Throughput: 130.50 samples/s
# Iteration [465] Latency: 0.9714s, Throughput: 131.76 samples/s
# Iteration [466] Latency: 0.9830s, Throughput: 130.22 samples/s
# Iteration [467] Latency: 1.0079s, Throughput: 127.00 samples/s
# Iteration [468] Latency: 0.9936s, Throughput: 128.83 samples/s
# Epoch [1/1] Latency: 518.2262s, Throughput: 115.78 samples/s

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## 8.2 Test Set Accuracy
# This function iterates over all minibatches to obtain a measure of accuracy over the full 10,000 samples in the test set.

# %%
total = 0
correct = 0

# drop_last switched to False to keep all samples
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data, targets in test_loader:
    data = data.to(device)
    targets = targets.to(device)

    # forward pass
    test_spk, _ = net(data.view(data.size(0), -1))

    # calculate total accuracy
    _, predicted = test_spk.sum(dim=0).max(1)
    total += targets.size(0)
    correct += (predicted == targets).sum().item()

print(f"Total correctly classified test set images: {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
# Out:
# Total correctly classified test set images: 9200/10000
# Test Set Accuracy: 92.00%

# %% [markdown]
# # **Piecewise Linear Surrogate Gradient Function**

# %% [markdown]
# The piecewise linear surrogate gradient can be defined as follows:
# grad
# (
# 𝑥
# )
# =
# max
# ⁡
# (
# 0
# ,
# 1
# −
# ∣
# 𝑥
# ∣
# )
# grad(x)=max(0,1−∣x∣)
#
# This function provides a linear approximation to the unit step function's gradient, which is efficient for both computation and hardware implementation.

# %%
import torch
import torch.nn as nn

# Leaky neuron model with a custom backward pass using piecewise linear surrogate gradient
class LeakySurrogate_p(nn.Module):
    def __init__(self, beta, threshold=1.0):
        super(LeakySurrogate_p, self).__init__()
        self.beta = beta
        self.threshold = threshold
        self.spike_gradient = self.PiecewiseLinear.apply

    def forward(self, input_, mem):
        spk = self.spike_gradient(mem - self.threshold)  # call the surrogate gradient function
        reset = (self.beta * spk * self.threshold).detach()  # remove reset from computational graph
        mem = self.beta * mem + input_ - reset  # Eq (1)
        return spk, mem

    # Forward pass: Heaviside function
    # Backward pass: Override Dirac Delta with the piecewise linear surrogate gradient
    @staticmethod
    class PiecewiseLinear(torch.autograd.Function):
        @staticmethod
        def forward(ctx, mem):
            spk = (mem > 0).float()  # Heaviside on the forward pass: Eq(2)
            ctx.save_for_backward(mem)  # store the membrane for use in the backward pass
            return spk

        @staticmethod
        def backward(ctx, grad_output):
            mem, = ctx.saved_tensors  # retrieve the membrane potential
            grad = (1 - torch.abs(mem)).clamp(min=0)  # Piecewise linear surrogate gradient
            grad = grad * grad_output
            return grad

# %%
# Network Architecture
num_inputs = 28 * 28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.95

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = LeakySurrogate_p(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = LeakySurrogate_p(beta=beta)

    def forward(self, x):
        # Initialize hidden states at t=0
        mem1 = torch.zeros(x.size(0), num_hidden, device=x.device)
        mem2 = torch.zeros(x.size(0), num_outputs, device=x.device)

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Outer training loop
for epoch in range(num_epochs):
    epoch_start_time = time.time()
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        iter_start_time = time.time()

        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

              #Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")

        iter_end_time = time.time()
        iter_latency = iter_end_time - iter_start_time
        throughput = batch_size / iter_latency
        print(f"Iteration [{iter_counter + 1}] Latency: {iter_latency:.4f}s, Throughput: {throughput:.2f} samples/s")

        counter += 1
        iter_counter += 1

    epoch_end_time = time.time()
    epoch_latency = epoch_end_time - epoch_start_time
    epoch_throughput = len(train_loader.dataset) / epoch_latency
    print(f"Epoch [{epoch + 1}/{num_epochs}] Latency: {epoch_latency:.4f}s, Throughput: {epoch_throughput:.2f} samples/s")
# Out:
# Epoch [1/1], Step [1], Train Loss: 60.4269, Test Loss: 52.6178
# Iteration [1] Latency: 0.3773s, Throughput: 339.23 samples/s
# Iteration [2] Latency: 0.3604s, Throughput: 355.15 samples/s
# Iteration [3] Latency: 0.3747s, Throughput: 341.65 samples/s
# Iteration [4] Latency: 0.3699s, Throughput: 346.08 samples/s
# Iteration [5] Latency: 0.3658s, Throughput: 349.94 samples/s
# Iteration [6] Latency: 0.3791s, Throughput: 337.66 samples/s
# Iteration [7] Latency: 0.3611s, Throughput: 354.43 samples/s
# Iteration [8] Latency: 0.3599s, Throughput: 355.68 samples/s
# Iteration [9] Latency: 0.3565s, Throughput: 359.02 samples/s
# Iteration [10] Latency: 0.3647s, Throughput: 350.97 samples/s
# Iteration [11] Latency: 0.3751s, Throughput: 341.28 samples/s
# Iteration [12] Latency: 0.3641s, Throughput: 351.52 samples/s
# Iteration [13] Latency: 0.3633s, Throughput: 352.29 samples/s
# Iteration [14] Latency: 0.3709s, Throughput: 345.13 samples/s
# Iteration [15] Latency: 0.3644s, Throughput: 351.26 samples/s
# Iteration [16] Latency: 0.3660s, Throughput: 349.73 samples/s
# Iteration [17] Latency: 0.3665s, Throughput: 349.22 samples/s
# Iteration [461] Latency: 0.5790s, Throughput: 221.06 samples/s
# Iteration [462] Latency: 0.5904s, Throughput: 216.80 samples/s
# Iteration [463] Latency: 0.5677s, Throughput: 225.49 samples/s
# Iteration [464] Latency: 0.6200s, Throughput: 206.46 samples/s
# Iteration [465] Latency: 0.4777s, Throughput: 267.96 samples/s
# Iteration [466] Latency: 0.3801s, Throughput: 336.71 samples/s
# Iteration [467] Latency: 0.3640s, Throughput: 351.68 samples/s
# Iteration [468] Latency: 0.3679s, Throughput: 347.88 samples/s
# Epoch [1/1] Latency: 208.5724s, Throughput: 287.67 samples/s

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import time

# Dataloader arguments
batch_size = 128
data_path = '/tmp/data/mnist'

# Device setup
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
    transforms.Resize((28, 28)),
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Initialize network
net = Net().to(device)
num_epochs = 1
loss_hist = []
test_loss_hist = []
counter = 0

# Loss and optimizer
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

# Variables to calculate average throughput
total_throughput = 0
total_iterations = 0

# Outer training loop
for epoch in range(num_epochs):
    epoch_start_time = time.time()
    iter_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data, targets in train_batch:
        iter_start_time = time.time()

        data = data.to(device)
        targets = targets.to(device)

        # forward pass
        net.train()
        spk_rec, mem_rec = net(data.view(batch_size, -1))

        # initialize the loss & sum over time
        loss_val = torch.zeros((1), dtype=dtype, device=device)
        for step in range(num_steps):
            loss_val += loss(mem_rec[step], targets)

        # Gradient calculation + weight update
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        with torch.no_grad():
            net.eval()
            test_data, test_targets = next(iter(test_loader))
            test_data = test_data.to(device)
            test_targets = test_targets.to(device)

            # Test set forward pass
            test_spk, test_mem = net(test_data.view(batch_size, -1))

            # Test set loss
            test_loss = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                test_loss += loss(test_mem[step], test_targets)
            test_loss_hist.append(test_loss.item())

              #Print train/test loss/accuracy
            if counter % 50 == 0:
                print(f"Epoch [{epoch + 1}/{num_epochs}], Step [{iter_counter + 1}], "
                      f"Train Loss: {loss_val.item():.4f}, Test Loss: {test_loss.item():.4f}")

        iter_end_time = time.time()
        iter_latency = iter_end_time - iter_start_time
        throughput = batch_size / iter_latency
        print(f"Iteration [{iter_counter + 1}] Latency: {iter_latency:.4f}s, Throughput: {throughput:.2f} samples/s")

        # Accumulate throughput for average calculation
        total_throughput += throughput
        total_iterations += 1

        counter += 1
        iter_counter += 1

    epoch_end_time = time.time()
    epoch_latency = epoch_end_time - epoch_start_time
    epoch_throughput = len(train_loader.dataset) / epoch_latency
# Iteration [441] Latency: 0.5739s, Throughput: 223.05 samples/s
# Iteration [442] Latency: 0.5599s, Throughput: 228.61 samples/s
# Iteration [443] Latency: 0.5713s, Throughput: 224.06 samples/s
# Iteration [444] Latency: 0.5941s, Throughput: 215.46 samples/s
# Iteration [445] Latency: 0.5354s, Throughput: 239.08 samples/s
# Iteration [446] Latency: 0.3722s, Throughput: 343.92 samples/s
# Iteration [447] Latency: 0.3594s, Throughput: 356.12 samples/s
# Iteration [448] Latency: 0.3698s, Throughput: 346.14 samples/s
# Iteration [449] Latency: 0.3711s, Throughput: 344.95 samples/s
# Iteration [450] Latency: 0.3630s, Throughput: 352.65 samples/s
# Epoch [1/1], Step [451], Train Loss: 6.7260, Test Loss: 6.8204
# Iteration [451] Latency: 0.3809s, Throughput: 336.09 samples/s
# Iteration [452] Latency: 0.3803s, Throughput: 336.57 samples/s
# Iteration [453] Latency: 0.3758s, Throughput: 340.56 samples/s
# Iteration [454] Latency: 0.3663s, Throughput: 349.42 samples/s
# Iteration [455] Latency: 0.3673s, Throughput: 348.52 samples/s
# Iteration [456] Latency: 0.3922s, Throughput: 326.39 samples/s
# Iteration [457] Latency: 0.3655s, Throughput: 350.25 samples/s
# Iteration [458] Latency: 0.3857s, Throughput: 331.86 samples/s
# Iteration [459] Latency: 0.3697s, Throughput: 346.26 samples/s
# Iteration [460] Latency: 0.3674s, Throughput: 348.38 samples/s
# Iteration [461] Latency: 0.3762s, Throughput: 340.27 samples/s
# Iteration [462] Latency: 0.3756s, Throughput: 340.79 samples/s
# Iteration [463] Latency: 0.3754s, Throughput: 340.99 samples/s
# Iteration [464] Latency: 0.3779s, Throughput: 338.67 samples/s
# Iteration [465] Latency: 0.3650s, Throughput: 350.73 samples/s
# Iteration [466] Latency: 0.3757s, Throughput: 340.70 samples/s
# Iteration [467] Latency: 0.3817s, Throughput: 335.35 samples/s
# Iteration [468] Latency: 0.3878s, Throughput: 330.10 samples/s
# Epoch [1/1] Latency: 219.5226s, Throughput: 273.32 samples/s
# Average Throughput: 313.28 samples/s

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.title("Loss Curves")
plt.legend(["Train Loss", "Test Loss"])
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# Voila! That's it for static MNIST. Feel free to tweak the network parameters, hyperparameters, decay rate, using a learning rate scheduler etc. to see if you can improve the network performance.

# %% [markdown]
# # Conclusion
# Now you know how to construct and train a fully-connected network on a static dataset. The spiking neurons can also be adapted to other layer types, including convolutions and skip connections. Armed with this knowledge, you should now be able to build many different types of SNNs. [In the next tutorial](https://snntorch.readthedocs.io/en/latest/tutorials/index.html), you will learn how to train a spiking convolutional network, and simplify the amount of code required using the `snn.backprop` module.
#
# Also, a special thanks to Bugra Kaytanli for providing valuable feedback on the tutorial.
#
# If you like this project, please consider starring ⭐ the repo on GitHub as it is the easiest and best way to support it.

# %% [markdown]
# # Additional Resources
#
# * [Check out the snnTorch GitHub project here.](https://github.com/jeshraghian/snntorch)
